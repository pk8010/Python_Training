# %% [markdown]
# Image Source https://www.w3schools.com/python/python_operators.asp

# %% [markdown]
# ### Operators
# Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.
#
# Operator Types
#
# Arithmetic operators
#
# Comparison (Relational) operators
#
# Logical (Boolean) operators
#
# Bitwise operators
#
# Assignment operators
#
# Special operators

# %% [markdown]
# ####  Identity Operators
#
# is and is not are the identity operators in Python.
#
# They are used to check if two values (or variables) are located on the same part of the memory.
#
# #### MemberShip Operators
#
# **in and not in** are the membership operators in Python.
#
# They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and   dictionary).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(28/5)
# Out:
# 5.6

# %% [markdown]
# ##### Python Assignment Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 25
x **= 5 
# x = x ** 5 
print(x)
# Out:
# 9765625

# %% [markdown]
# #### Python Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 9
y = 9


# if x >= y:
#     print("x and y is not same")

# if ((x == y) or (x%2==0)):
#     print("x is same as y")
# else:
#     print("x is not same as y")

# print(x >= y)


x = 15
if (x < 5 and x < 10):
    print("x is same as y")
else:
    print("x is not same as y")
# Out:
# x is not same as y

# %% [markdown]
# #### Python Logical Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 15
if (x < 5 and x < 10):
    print("x is same as y")
else:
    print("x is not same as y")
# Out:
# x is not same as y

# %% [markdown]
# ##### Python Identity Operator
#
# ![image.png](attachment:image.png)

# %%
x = 1.1
y = 1.1



print(x is y)


# print(x is not y)

print(id(x))
print(id(y))
# print(x)


# x = ["apple", "banana"]
# y = ["apple", "banana"]
# y[0] = 'you'

# x=10
# y=10
# z=10

# print(id(x))
# print(id(y))
# print(id(z))



# x = "apple"
# y = "apple"

x = ["apple", "banana",]
y = ["apple", "banana"]
# y = x


# z = x

# print(x is z)

# returns True because z is the same object as x

print(x == y)

# returns False because x is not the same object as y, even if they have the same content

# print(x == y)

# to demonstrate the difference betweeen "is" and "==": this comparison returns True because x is equal to y

# %% [markdown]
# #### Python Membership Operators
#
# ![image.png](attachment:image.png)

# %%
list1 = [2,3,4,5,6]
string1 = "this is a book this is a book this is a book this is a book"
# list2 = (2,3,4,5,6)
# list3 = {'name':"abc", 'age':'56'}



# print('book' in string1)
# print('ad' in list3)
vowel_list = ['a','e','i','o','u',' ']
var = 0
for char in string1:
    if char not in vowel_list:
        var += 1
#     if char == 'a' or char == 'e' or char == 'i' or :
#         var += 1        
print(var)

# %% [markdown]
# #### Python Bitwise Operators
#
# ![image.png](attachment:image.png)

# %%
~5
# Out:
# -6

# %% [markdown]
# ### Python if ... else Statement

# %%
num = 25

# if print('Hi'):   
#     print("this will print")

if num < 11:    
    print("num is smaller than 11")
elif num >11 and num < 20:
    print("num >11 and number < 20")    
else:
    print("num is gereter than 20")
    
    
    
# Nested If else
num = 10

if num>=0:
    if num>=11:
        print("the number is greater than 11")
    else:
        print("the number is less than 11")
else:
    print("Number is a negative number")

# Python program to find the largest element among three Numbers
# Out:
# num is gereter than 20
# the number is less than 11
